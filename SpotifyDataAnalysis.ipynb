# %%
# Importing the libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading the Data Sets

# %%
df2=pd.read_csv('artists.csv')

# %%
df2.head()
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %%
df2['id'].count()
# Out:
# 1104349

# %%
df=pd.read_csv('tracks.csv')

# %% [markdown]
# 📁 tracks.csv
#
# Detailed data about individual tracks:
#
# id: Unique identifier for each track.
# name: The name/title of the track.
# popularity: Track popularity score on Spotify (0–100).
# duration_ms: Duration of the track in milliseconds.
# explicit: Boolean indicator of whether the track has explicit content.
# artists: List of artist names featured in the track.
# id_artists: Corresponding list of artist IDs for reference and joins.
# release_date: The track’s release date.
# danceability, energy: Audio features calculated by Spotify’s algorithm, representing the musical feel of the track.

# %%
df
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# 0                6       126903         0                          ['Uli']
# 1                0        98200         0              ['Fernando Pessoa']
# 2                0       181640         0              ['Ignacio Corsini']
# 3                0       176907         0              ['Ignacio Corsini']
# 4                0       163080         0                  ['Dick Haymes']
# ...            ...          ...       ...                              ...
# 586667          50       258267         0                      ['阿YueYue']
# 586668          72       153293         0                   ['ROLE MODEL']
# 586669          70       187601         0                      ['FINNEAS']
# 586670          58       142003         0  ['Gentle Bones', 'Clara Benin']
# 586671          38       214360         0                    ['Afrosound']
#
#                                                id_artists release_date  \
# 0                              ['45tIt06XoI0Iio4LBEVpls']   1922-02-22
# 1                              ['14jtPCOoNZwquk5wd9DxrY']   1922-06-01
# 2                              ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 3                              ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 4                              ['3BiJGZsyX9sJchTqcSA7Su']         1922
# ...                                                   ...          ...
# 586667                         ['1QLBXKM5GCpyQQSVMNZqrZ']   2020-09-26
# 586668                         ['1dy5WNgIKQU6ezkpZs4y8z']   2020-10-21
# 586669                         ['37M5pPGs6V1fchFJSgCguX']   2020-09-02
# 586670  ['4jGPdu95icCKVF31CcFKbS', '5ebPSE9YI5aLeZ1Z2g...   2021-03-05
# 586671                         ['0i4Qda0k4nf7jnNHmSNpYv']   2015-07-01
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.645  0.4450    0   -13.338     1       0.4510         0.674
# 1              0.695  0.2630    0   -22.136     1       0.9570         0.797
# 2              0.434  0.1770    1   -21.180     1       0.0512         0.994
# 3              0.321  0.0946    7   -27.961     1       0.0504         0.995
# 4              0.402  0.1580    3   -16.900     0       0.0390         0.989
# ...              ...     ...  ...       ...   ...          ...           ...
# 586667         0.560  0.5180    0    -7.471     0       0.0292         0.785
# 586668         0.765  0.6630    0    -5.223     1       0.0652         0.141
# 586669         0.535  0.3140    7   -12.823     0       0.0408         0.895
# 586670         0.696  0.6150   10    -6.212     1       0.0345         0.206
# 586671         0.686  0.7230    6    -7.067     1       0.0363         0.105
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 0               0.744000    0.1510   0.1270  104.851               3
# 1               0.000000    0.1480   0.6550  102.009               1
# 2               0.021800    0.2120   0.4570  130.418               5
# 3               0.918000    0.1040   0.3970  169.980               3
# 4               0.130000    0.3110   0.1960  103.220               4
# ...                  ...       ...      ...      ...             ...
# 586667          0.000000    0.0648   0.2110  131.896               4
# 586668          0.000297    0.0924   0.6860  150.091               4
# 586669          0.000150    0.0874   0.0663  145.095               4
# 586670          0.000003    0.3050   0.4380   90.029               4
# 586671          0.000000    0.2640   0.9750  112.204               4
#
# [586672 rows x 20 columns]

# %% [markdown]
# 🔍 How You Can Use This Dataset
#
# You can use this data to explore and answer questions such as:
# Artist Popularity Trends: Who are the most followed or popular artists? Which genres dominate Spotify?
# Track Insights: How do explicit tracks compare with clean tracks in terms of popularity or energy?
# Genre & Era Evolution: How have track characteristics like danceability or energy changed over time?
# Audio Feature Correlations: What is the relationship between track popularity and Spotify’s audio features like energy or danceability?
# Music Discovery Models: Use the artist and track data together for building music recommendation systems or clustering tracks by audio mood.
#
# Whether you're a data analyst, music tech enthusiast, or someone experimenting with Spotify data, this dataset provides a great starting point for in-depth analysis.

# %%
df.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
#  16  liveness          586672 non-null  float64
#  17  valence           586672 non-null  float64
#  18  tempo             586672 non-null  float64
#  19  time_signature    586672 non-null  int64
# dtypes: float64(9), int64(6), object(5)
# memory usage: 89.5+ MB

# %%
df.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
df.shape
# Out:
# (586672, 20)

# %%
df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450    0   -13.338     1       0.4510
# 1   1922-06-01         0.695  0.2630    0   -22.136     1       0.9570
# 2   1922-03-21         0.434  0.1770    1   -21.180     1       0.0512
# 3   1922-03-21         0.321  0.0946    7   -27.961     1       0.0504
# 4         1922         0.402  0.1580    3   -16.900     0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674            0.7440     0.151    0.127  104.851               3
# 1         0.797            0.0000     0.148    0.655  102.009               1
# 2         0.994            0.0218     0.212    0.457  130.418               5
# 3         0.995            0.9180     0.104    0.397  169.980               3
# 4         0.989            0.1300     0.311    0.196  103.220               4

# %%
#Check for missing values

df.isnull().sum()
df=df.dropna()

# %%
df.shape
# Out:
# (586601, 20)

# %%
#Converting release date to datetime format

df['release_date']=pd.to_datetime(df['release_date'],errors='coerce')
# Out:
# /var/folders/v6/b6p52t217dl0zncsqc790k4m0000gn/T/ipykernel_74529/237777611.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['release_date']=pd.to_datetime(df['release_date'],errors='coerce')

# %%
df.describe()
# Out:
#           popularity   duration_ms       explicit  \
# count  586601.000000  5.866010e+05  586601.000000
# mean       27.573212  2.300549e+05       0.044091
# min         0.000000  3.344000e+03       0.000000
# 25%        13.000000  1.750830e+05       0.000000
# 50%        27.000000  2.149070e+05       0.000000
# 75%        41.000000  2.638670e+05       0.000000
# max       100.000000  5.621218e+06       1.000000
# std        18.369417  1.265328e+05       0.205298
#
#                         release_date   danceability         energy  \
# count                         448010  586601.000000  586601.000000
# mean   1993-03-23 09:16:40.761590016       0.563612       0.542071
# min              1900-01-01 00:00:00       0.000000       0.000000
# 25%              1980-01-01 00:00:00       0.453000       0.343000
# 50%              1997-01-01 00:00:00       0.577000       0.549000
# 75%              2011-01-01 00:00:00       0.686000       0.748000
# max              2021-04-16 00:00:00       0.991000       1.000000
# std                              NaN       0.166101       0.251910
#
#                  key       loudness           mode    speechiness  \
# count  586601.000000  586601.000000  586601.000000  586601.000000
# mean        5.221594     -10.205789       0.658797       0.104870
# min         0.000000     -60.000000       0.000000       0.000000
# 25%         2.000000     -12.891000       0.000000       0.034000
# 50%         5.000000      -9.242000       1.000000       0.044300
# 75%         8.000000      -6.481000       1.000000       0.076300
# max        11.000000       5.376000       1.000000       0.971000
# std         3.519420       5.089422       0.474114       0.179902
#
#         acousticness  instrumentalness       liveness        valence  \
# count  586601.000000     586601.000000  586601.000000  586601.000000
# mean        0.449803          0.113425       0.213933       0.552306
# min         0.000000          0.000000       0.000000       0.000000
# 25%         0.096900          0.000000       0.098300       0.346000
# 50%         0.422000          0.000024       0.139000       0.564000
# 75%         0.784000          0.009550       0.278000       0.769000
# max         0.996000          1.000000       1.000000       1.000000
# std         0.348812          0.266843       0.184328       0.257673
#
#                tempo  time_signature
# count  586601.000000   586601.000000
# mean      118.467930        3.873410
# min         0.000000        0.000000
# 25%        95.606000        4.000000
# 50%       117.387000        4.000000
# 75%       136.324000        4.000000
# max       246.381000        5.000000
# std        29.762942        0.473112

# %%
# converting duration in millisecond to seconds
df['duration_min']=df['duration_ms']/60000
# Out:
# /var/folders/v6/b6p52t217dl0zncsqc790k4m0000gn/T/ipykernel_74529/3761467110.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['duration_min']=df['duration_ms']/60000

# %%
df.describe()
# Out:
#           popularity   duration_ms       explicit  \
# count  586601.000000  5.866010e+05  586601.000000
# mean       27.573212  2.300549e+05       0.044091
# min         0.000000  3.344000e+03       0.000000
# 25%        13.000000  1.750830e+05       0.000000
# 50%        27.000000  2.149070e+05       0.000000
# 75%        41.000000  2.638670e+05       0.000000
# max       100.000000  5.621218e+06       1.000000
# std        18.369417  1.265328e+05       0.205298
#
#                         release_date   danceability         energy  \
# count                         448010  586601.000000  586601.000000
# mean   1993-03-23 09:16:40.761590016       0.563612       0.542071
# min              1900-01-01 00:00:00       0.000000       0.000000
# 25%              1980-01-01 00:00:00       0.453000       0.343000
# 50%              1997-01-01 00:00:00       0.577000       0.549000
# 75%              2011-01-01 00:00:00       0.686000       0.748000
# max              2021-04-16 00:00:00       0.991000       1.000000
# std                              NaN       0.166101       0.251910
#
#                  key       loudness           mode    speechiness  \
# count  586601.000000  586601.000000  586601.000000  586601.000000
# mean        5.221594     -10.205789       0.658797       0.104870
# min         0.000000     -60.000000       0.000000       0.000000
# 25%         2.000000     -12.891000       0.000000       0.034000
# 50%         5.000000      -9.242000       1.000000       0.044300
# 75%         8.000000      -6.481000       1.000000       0.076300
# max        11.000000       5.376000       1.000000       0.971000
# std         3.519420       5.089422       0.474114       0.179902
#
#         acousticness  instrumentalness       liveness        valence  \
# count  586601.000000     586601.000000  586601.000000  586601.000000
# mean        0.449803          0.113425       0.213933       0.552306
# min         0.000000          0.000000       0.000000       0.000000
# 25%         0.096900          0.000000       0.098300       0.346000
# 50%         0.422000          0.000024       0.139000       0.564000
# 75%         0.784000          0.009550       0.278000       0.769000
# max         0.996000          1.000000       1.000000       1.000000
# std         0.348812          0.266843       0.184328       0.257673
#
#                tempo  time_signature   duration_min
# count  586601.000000   586601.000000  586601.000000
# mean      118.467930        3.873410       3.834248
# min         0.000000        0.000000       0.055733
# 25%        95.606000        4.000000       2.918050
# 50%       117.387000        4.000000       3.581783
# 75%       136.324000        4.000000       4.397783
# max       246.381000        5.000000      93.686967
# std        29.762942        0.473112       2.108880

# %% [markdown]
# ## Exploratry Data Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['popularity'], bins=50)
plt.title('Track Popularity Distribution')
plt.show()

# %%
df['popularity'].hist(bins=50)
# Out:
# <Axes: >

# %%
# Mean, Median of Songs popularity

# %%
df['popularity'].median()
# Out:
# 27.0

# %%
df['popularity'].mean()
# Out:
# 27.573212456166967

# %% [markdown]
# #### Inferences
#
# ✅ Popularity parameter is Approximately Symmetric and Unimodal
# In other words:
#
# The data is not heavily skewed.
# The distribution is likely normal or close to bell-shaped.

# %% [markdown]
# ### Corelarion

# %%
df.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'duration_min'],
#       dtype='object')

# %%
features = ['danceability', 'energy', 'speechiness', 'acousticness', 
            'instrumentalness', 'liveness', 'valence', 'tempo', 'popularity','duration_min']

corr = df[features].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Feature Correlation Matrix')
plt.show()

# %% [markdown]
# #### Inference:
#
# From corelation matrix we are interested to find how different features influence popularity of the Songs. None of the features are directly influcincing popularity strongly except the feature 'energy' which have a corelation coefficint of +0.3

# %% [markdown]
# ### Popularity of songs for Explicit and Non-explicit Tracks
#
# Inference: Explit content tracks have better popularity ratings compared to non-explicit tracks.

# %%
sns.boxplot(x='explicit', y='popularity', data=df)
plt.title('Popularity: Explicit vs. Non-explicit Tracks')
plt.show()

# %%
## Ploting how features have changes over the last 100 years

df['release_date']=pd.to_datetime(df['release_date'])
df['year'] = df['release_date'].dt.year
yearly_avg = df.groupby('year')[['danceability', 'energy', 'popularity']].mean().reset_index()

plt.figure(figsize=(12,6))
for feature in ['popularity']:
    plt.plot(yearly_avg['year'], yearly_avg[feature], label=feature)

plt.title('Trend of Popularity Over Time')
plt.xlabel('Year')
plt.ylabel('Average Value')
plt.legend()
plt.show()
# Out:
# /var/folders/v6/b6p52t217dl0zncsqc790k4m0000gn/T/ipykernel_74529/2171570545.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['release_date']=pd.to_datetime(df['release_date'])
# /var/folders/v6/b6p52t217dl0zncsqc790k4m0000gn/T/ipykernel_74529/2171570545.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['release_date'].dt.year

# %% [markdown]
# ### Inference:
#
# The avarage popularity of the songs show dip from 1900 to 1920 and then goes on to increase ofr the next 100 years.

# %%
df['year'] = df['release_date'].dt.year
yearly_avg = df.groupby('year')[['danceability', 'energy', 'popularity']].mean().reset_index()

plt.figure(figsize=(12,6))
for feature in ['danceability']:
    plt.plot(yearly_avg['year'], yearly_avg[feature], label=feature)

plt.title('Trend of Danceability Over Time')
plt.xlabel('Year')
plt.ylabel('Average Value')
plt.legend()
plt.show()
# Out:
# /var/folders/v6/b6p52t217dl0zncsqc790k4m0000gn/T/ipykernel_74529/3004762769.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['release_date'].dt.year

# %%
#yearly_songs

# %%
df['year'] = df['release_date'].dt.year
yearly_avg = df.groupby('year')[['danceability', 'energy', 'popularity']].mean().reset_index()

plt.figure(figsize=(12,6))
for feature in ['energy']:
    plt.plot(yearly_avg['year'], yearly_avg[feature], label=feature)

plt.title('Trend of Energy Over Time')
plt.xlabel('Year')
plt.ylabel('Average Value')
plt.legend()
plt.show()
# Out:
# /var/folders/v6/b6p52t217dl0zncsqc790k4m0000gn/T/ipykernel_74529/1186557451.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['release_date'].dt.year

# %% [markdown]
# #### Inferences:
#
# Popularity and Energy show gradualy rise from 1920 to 2010, shows popularity and the energy in the songs have impproved gradually over a perod of 100 years.
#
# Danceability: This parameter shows fluctuation between 1920 and 1940, indicating presence of good daceability tracks during those 20 years, then from 1940 the daceability undergoes gradual increase for next 80 years.

# %% [markdown]
# ## Trend of songs produced over time

# %%
yearly_songs=df.groupby('year')['id'].count().reset_index()

# %%
yearly_songs.plot(x='year', y='id', kind='line')
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ### Inference
#
# We can see exponential increase in no. of tracks being produced over a period of 100 years.

# %%
#df2

# %%
df2.columns
# Out:
# Index(['id', 'followers', 'genres', 'name', 'popularity'], dtype='object')

# %%
df2.rename(columns={'id': 'id_artists'}, inplace=True)

# %%
df2.columns
# Out:
# Index(['id_artists', 'followers', 'genres', 'name', 'popularity'], dtype='object')

# %%
import ast

# Convert from string to actual list, then extract the first element
df['id_artists'] = df['id_artists'].apply(lambda x: ast.literal_eval(x)[0])
# Out:
# /var/folders/v6/b6p52t217dl0zncsqc790k4m0000gn/T/ipykernel_74529/2703627790.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['id_artists'] = df['id_artists'].apply(lambda x: ast.literal_eval(x)[0])

# %%
df['id_artists']
# Out:
# 0         45tIt06XoI0Iio4LBEVpls
# 1         14jtPCOoNZwquk5wd9DxrY
# 2         5LiOoJbxVSAMkBS2fUm3X2
# 3         5LiOoJbxVSAMkBS2fUm3X2
# 4         3BiJGZsyX9sJchTqcSA7Su
#                    ...
# 586667    1QLBXKM5GCpyQQSVMNZqrZ
# 586668    1dy5WNgIKQU6ezkpZs4y8z
# 586669    37M5pPGs6V1fchFJSgCguX
# 586670    4jGPdu95icCKVF31CcFKbS
# 586671    0i4Qda0k4nf7jnNHmSNpYv
# Name: id_artists, Length: 586601, dtype: object

# %%
df = df.merge(df2[['id_artists', 'followers']], on='id_artists', how='left')

# %%
df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists              id_artists  \
# 0       126903         0              ['Uli']  45tIt06XoI0Iio4LBEVpls
# 1        98200         0  ['Fernando Pessoa']  14jtPCOoNZwquk5wd9DxrY
# 2       181640         0  ['Ignacio Corsini']  5LiOoJbxVSAMkBS2fUm3X2
# 3       176907         0  ['Ignacio Corsini']  5LiOoJbxVSAMkBS2fUm3X2
# 4       163080         0      ['Dick Haymes']  3BiJGZsyX9sJchTqcSA7Su
#
#   release_date  danceability  energy  ...  speechiness  acousticness  \
# 0   1922-02-22         0.645  0.4450  ...       0.4510         0.674
# 1   1922-06-01         0.695  0.2630  ...       0.9570         0.797
# 2   1922-03-21         0.434  0.1770  ...       0.0512         0.994
# 3   1922-03-21         0.321  0.0946  ...       0.0504         0.995
# 4          NaT         0.402  0.1580  ...       0.0390         0.989
#
#    instrumentalness  liveness  valence    tempo  time_signature  duration_min  \
# 0            0.7440     0.151    0.127  104.851               3      2.115050
# 1            0.0000     0.148    0.655  102.009               1      1.636667
# 2            0.0218     0.212    0.457  130.418               5      3.027333
# 3            0.9180     0.104    0.397  169.980               3      2.948450
# 4            0.1300     0.311    0.196  103.220               4      2.718000
#
#      year  followers
# 0  1922.0       91.0
# 1  1922.0        3.0
# 2  1922.0     3528.0
# 3  1922.0     3528.0
# 4     NaN    11327.0
#
# [5 rows x 23 columns]

# %%
df2.sort_values(['followers'],ascending=False)
# Out:
#                     id_artists   followers  \
# 144138  6eUKZXaKkcviH0Ku9w2n3V  78900234.0
# 144485  66CXWjxzNUsdJxJ2JdwvnR  61301006.0
# 313676  3TVXtAsR1Inumwj472S9r4  54416812.0
# 144481  1uNFoZAHBGtllmzznpCI3s  44606973.0
# 144488  7dGJo4pcD2V6oG8kP0tJRR  43747833.0
# ...                        ...         ...
# 468526  6jkpqSWWsXSuqtsoeAiMDU         NaN
# 468527  7aMdHPv79qOuqqBD6TnaCp         NaN
# 468528  2lr0R5vHGfI0C489h0r6qV         NaN
# 468529  0xkSOIeyeTILNIOZKyFgaP         NaN
# 468530  4EqqnE0XMAcreVF84QGYJ0         NaN
#
#                                                    genres  \
# 144138                                  ['pop', 'uk pop']
# 144485                           ['pop', 'post-teen pop']
# 313676  ['canadian hip hop', 'canadian pop', 'hip hop'...
# 144481           ['canadian pop', 'pop', 'post-teen pop']
# 144488              ['detroit hip hop', 'hip hop', 'rap']
# ...                                                   ...
# 468526                                   ['uk americana']
# 468527                                                 []
# 468528                                       ['dc indie']
# 468529                                                 []
# 468530                                                 []
#
#                                                      name  popularity
# 144138                                         Ed Sheeran          92
# 144485                                      Ariana Grande          95
# 313676                                              Drake          98
# 144481                                      Justin Bieber         100
# 144488                                             Eminem          94
# ...                                                   ...         ...
# 468526                                   Police Dog Hogan          14
# 468527                Miles Davis & Charlie "Bird" Parker           0
# 468528                                    Black Dog Prowl          16
# 468529  Band of the Fifteenth Field Artillery Regiment...           3
# 468530                             Robert Steven Williams           0
#
# [1104349 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'duration_min',
#        'year', 'followers'],
#       dtype='object')

# %%
#df.head()

# %%
#df['followers'].value_counts()

# %%
#df2.rename(columns={'id': 'id_artists'}, inplace=True)
df2.rename(columns={'id':'id_artists'},inplace=True)

# %%
df2.head()
# Out:
#                id_artists  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %%
import ast

df['artists'] = df['artists'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
df['main_artist'] = df['artists'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None)

# %%
df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit            artists              id_artists  \
# 0       126903         0              [Uli]  45tIt06XoI0Iio4LBEVpls
# 1        98200         0  [Fernando Pessoa]  14jtPCOoNZwquk5wd9DxrY
# 2       181640         0  [Ignacio Corsini]  5LiOoJbxVSAMkBS2fUm3X2
# 3       176907         0  [Ignacio Corsini]  5LiOoJbxVSAMkBS2fUm3X2
# 4       163080         0      [Dick Haymes]  3BiJGZsyX9sJchTqcSA7Su
#
#   release_date  danceability  energy  ...  acousticness  instrumentalness  \
# 0   1922-02-22         0.645  0.4450  ...         0.674            0.7440
# 1   1922-06-01         0.695  0.2630  ...         0.797            0.0000
# 2   1922-03-21         0.434  0.1770  ...         0.994            0.0218
# 3   1922-03-21         0.321  0.0946  ...         0.995            0.9180
# 4          NaT         0.402  0.1580  ...         0.989            0.1300
#
#    liveness  valence    tempo  time_signature  duration_min    year  \
# 0     0.151    0.127  104.851               3      2.115050  1922.0
# 1     0.148    0.655  102.009               1      1.636667  1922.0
# 2     0.212    0.457  130.418               5      3.027333  1922.0
# 3     0.104    0.397  169.980               3      2.948450  1922.0
# 4     0.311    0.196  103.220               4      2.718000     NaN
#
#    followers      main_artist
# 0       91.0              Uli
# 1        3.0  Fernando Pessoa
# 2     3528.0  Ignacio Corsini
# 3     3528.0  Ignacio Corsini
# 4    11327.0      Dick Haymes
#
# [5 rows x 24 columns]

# %%
df_final=df.merge(df2[['id_artists','followers']],on='id_artists',how='left')

# %%
features = ['danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness',
            'liveness', 'valence', 'loudness', 'tempo']

# %%
# 11. Clustering songs by audio features (KMeans example)
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

X = df_final[features].dropna()
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

kmeans = KMeans(n_clusters=4, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

df_final.loc[X.index, 'cluster'] = clusters

plt.figure(figsize=(10,6))
sns.scatterplot(x='danceability', y='energy', hue='cluster', data=df_final, palette='Set2')
plt.title('KMeans Clustering of Songs by Danceability and Energy')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df_final.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'duration_min',
#        'year', 'followers_x', 'main_artist', 'followers_y', 'cluster'],
#       dtype='object')

# %%
# Check for null values
df_final.isnull().sum()
# Out:
# id                       0
# name                     0
# popularity               0
# duration_ms              0
# explicit                 0
# artists                  0
# id_artists               0
# release_date        138591
# danceability             0
# energy                   0
# key                      0
# loudness                 0
# mode                     0
# speechiness              0
# acousticness             0
# instrumentalness         0
# liveness                 0
# valence                  0
# tempo                    0
# time_signature           0
# duration_min             0
# year                138591
# followers_x          12345
# main_artist              0
# followers_y          12345
# cluster                  0
# dtype: int64

# %%
df_clean = df_final.dropna(subset=['danceability', 'energy', 'loudness', 'instrumentalness', 'name', 'main_artist'])

# %% [markdown]
# ## Finding top Artists by Popularity

# %%
#!pip install streamlit

df2.shape
# Out:
# (1104349, 5)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104349 entries, 0 to 1104348
# Data columns (total 5 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   id_artists  1104349 non-null  object
#  1   followers   1104336 non-null  float64
#  2   genres      1104349 non-null  object
#  3   name        1104346 non-null  object
#  4   popularity  1104349 non-null  int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 42.1+ MB

# %%
df_artists_pop=df2.groupby(['name'])['followers'].max().reset_index()

# %%
df_artists_pop.sort_values(['followers'],ascending=False).head(10)
# Out:
#                    name   followers
# 273751       Ed Sheeran  78900234.0
# 64561     Ariana Grande  61301006.0
# 261770            Drake  54416812.0
# 478971    Justin Bieber  44606973.0
# 288961           Eminem  43747833.0
# 780369          Rihanna  42244011.0
# 108026    Billie Eilish  41792604.0
# 901390     Taylor Swift  38869193.0
# 410659  Imagine Dragons  33665795.0
# 752033            Queen  33483326.0

# %%
df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit            artists              id_artists  \
# 0       126903         0              [Uli]  45tIt06XoI0Iio4LBEVpls
# 1        98200         0  [Fernando Pessoa]  14jtPCOoNZwquk5wd9DxrY
# 2       181640         0  [Ignacio Corsini]  5LiOoJbxVSAMkBS2fUm3X2
# 3       176907         0  [Ignacio Corsini]  5LiOoJbxVSAMkBS2fUm3X2
# 4       163080         0      [Dick Haymes]  3BiJGZsyX9sJchTqcSA7Su
#
#   release_date  danceability  energy  ...  acousticness  instrumentalness  \
# 0   1922-02-22         0.645  0.4450  ...         0.674            0.7440
# 1   1922-06-01         0.695  0.2630  ...         0.797            0.0000
# 2   1922-03-21         0.434  0.1770  ...         0.994            0.0218
# 3   1922-03-21         0.321  0.0946  ...         0.995            0.9180
# 4          NaT         0.402  0.1580  ...         0.989            0.1300
#
#    liveness  valence    tempo  time_signature  duration_min    year  \
# 0     0.151    0.127  104.851               3      2.115050  1922.0
# 1     0.148    0.655  102.009               1      1.636667  1922.0
# 2     0.212    0.457  130.418               5      3.027333  1922.0
# 3     0.104    0.397  169.980               3      2.948450  1922.0
# 4     0.311    0.196  103.220               4      2.718000     NaN
#
#    followers      main_artist
# 0       91.0              Uli
# 1        3.0  Fernando Pessoa
# 2     3528.0  Ignacio Corsini
# 3     3528.0  Ignacio Corsini
# 4    11327.0      Dick Haymes
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'duration_min',
#        'year', 'followers', 'main_artist'],
#       dtype='object')

# %% [markdown]
# ## Song suggestion algorithm

# %%
df.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'duration_min',
#        'year', 'followers', 'main_artist'],
#       dtype='object')

# %%
features = ['year', 'danceability', 'energy', 'followers']

# %%
X = df[features].copy()

# %%
X = X.fillna(0)

# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler

# %%
# Standardize the features
scaler = StandardScaler() 
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# #### Train KNN model

# %%
knn = NearestNeighbors(n_neighbors=5, metric='euclidean')
knn.fit(X_scaled)
# Out:
# NearestNeighbors(metric='euclidean')

# %%
df.describe()
# Out:
#           popularity   duration_ms       explicit  \
# count  586601.000000  5.866010e+05  586601.000000
# mean       27.573212  2.300549e+05       0.044091
# min         0.000000  3.344000e+03       0.000000
# 25%        13.000000  1.750830e+05       0.000000
# 50%        27.000000  2.149070e+05       0.000000
# 75%        41.000000  2.638670e+05       0.000000
# max       100.000000  5.621218e+06       1.000000
# std        18.369417  1.265328e+05       0.205298
#
#                         release_date   danceability         energy  \
# count                         448010  586601.000000  586601.000000
# mean   1993-03-23 09:16:40.761590016       0.563612       0.542071
# min              1900-01-01 00:00:00       0.000000       0.000000
# 25%              1980-01-01 00:00:00       0.453000       0.343000
# 50%              1997-01-01 00:00:00       0.577000       0.549000
# 75%              2011-01-01 00:00:00       0.686000       0.748000
# max              2021-04-16 00:00:00       0.991000       1.000000
# std                              NaN       0.166101       0.251910
#
#                  key       loudness           mode    speechiness  \
# count  586601.000000  586601.000000  586601.000000  586601.000000
# mean        5.221594     -10.205789       0.658797       0.104870
# min         0.000000     -60.000000       0.000000       0.000000
# 25%         2.000000     -12.891000       0.000000       0.034000
# 50%         5.000000      -9.242000       1.000000       0.044300
# 75%         8.000000      -6.481000       1.000000       0.076300
# max        11.000000       5.376000       1.000000       0.971000
# std         3.519420       5.089422       0.474114       0.179902
#
#         acousticness  instrumentalness       liveness        valence  \
# count  586601.000000     586601.000000  586601.000000  586601.000000
# mean        0.449803          0.113425       0.213933       0.552306
# min         0.000000          0.000000       0.000000       0.000000
# 25%         0.096900          0.000000       0.098300       0.346000
# 50%         0.422000          0.000024       0.139000       0.564000
# 75%         0.784000          0.009550       0.278000       0.769000
# max         0.996000          1.000000       1.000000       1.000000
# std         0.348812          0.266843       0.184328       0.257673
#
#                tempo  time_signature   duration_min           year  \
# count  586601.000000   586601.000000  586601.000000  448010.000000
# mean      118.467930        3.873410       3.834248    1992.823540
# min         0.000000        0.000000       0.055733    1900.000000
# 25%        95.606000        4.000000       2.918050    1980.000000
# 50%       117.387000        4.000000       3.581783    1997.000000
# 75%       136.324000        4.000000       4.397783    2011.000000
# max       246.381000        5.000000      93.686967    2021.000000
# std        29.762942        0.473112       2.108880      21.310965
#
#           followers
# count  5.742560e+05
# mean   1.106969e+06
# min    0.000000e+00
# 25%    1.247900e+04
# 50%    9.723200e+04
# 75%    6.130600e+05
# max    7.890023e+07
# std    3.917443e+06

# %%
print("Please provide the following inputs:")

year= int(input("Release Year (e.g., 1900 to 2025): "))
danceability = float(input("Danceability (0.0 to 1.0): "))
energy = float(input("Energy (0.0 to 1.0): "))
followers = int(input("Artist Followers (e.g., 1000 to 100000000): "))
# Out:
# Please provide the following inputs:

# %%
user_input = [[year, danceability, energy, followers]]

# %%
# Standardize user input
user_input_scaled = scaler.transform(user_input)

# %%
# Find nearest neighbors
distances, indices = knn.kneighbors(user_input_scaled)

# %%
# Fetch top 5 recommendations
print("\n🎵 Top 5 Recommended Songs for You:\n")

for idx in indices[0]:
    song_name = df.iloc[idx]['name']
    artist_name = df.iloc[idx]['artists']
    popularity = df.iloc[idx]['popularity']
    artist_followers = df.iloc[idx]['followers']
    Release_year=df.iloc[idx]['year']
    dancebility=df.iloc[idx]['danceability']
    energy=df.iloc[idx]['energy']
    #Release_year=df.iloc[idx]['year']
    
    print(f"Song: {song_name}")
    print(f"Artist: {artist_name}")
    print(f"Popularity: {popularity}")
    print(f"Followers: {artist_followers}")
    print(f"Year: {Release_year}")
    print(f"Danceability: {dancebility}")
    print(f"energy: {energy}")
    print("-" * 40)
